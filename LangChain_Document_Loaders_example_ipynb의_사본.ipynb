# %% [markdown]
# <a href="https://colab.research.google.com/github/minyi-k03/LargeLanguageModel/blob/Project-Based-Learning(PBL)/LangChain_Document_Loaders_example_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 랭체인(LangChain) DataLoaders 예제
# ## 작성자 : AISchool ( http://aischool.ai/%ec%98%a8%eb%9d%bc%ec%9d%b8-%ea%b0%95%ec%9d%98-%ec%b9%b4%ed%85%8c%ea%b3%a0%eb%a6%ac/ )
# ## Reference : https://python.langchain.com/docs/modules/data_connection/document_loaders/

# %% [markdown]
# **Document Loaders**의 종류를 크게 분류하면 다음과 같습니다.
#
# 1. WebBaseLoader
# 2. CSV
# 3. File Directory
# 4. HTML
# 5. JSON
# 6. Markdown
# 7. PDF

# %% [markdown]
# # LangChain 라이브러리 설치

# %%
# !pip install -q -U langchain langchain-community langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 29.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.

# %% [markdown]
# # 1. WebBaseLoader
# **WebBaseLoader**는 URL로부터 HTML 페이지의 모든 text를 load합니다.

# %%
from langchain_community.document_loaders import WebBaseLoader
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader = WebBaseLoader("https://www.espn.com/")

# %%
data = loader.load()

# %%
data
# Out:
# [Document(metadata={'source': 'https://www.espn.com/', 'title': 'ESPN - Serving Sports Fans. Anytime. Anywhere.', 'description': 'Visit ESPN for live scores, highlights and sports news. Stream exclusive games on ESPN and play fantasy sports.', 'language': 'en'}, page_content="\n\n\n\n\n\n\n\n\nESPN - Serving Sports Fans. Anytime. Anywhere.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n        Skip to main content\n    \n\n        Skip to navigation\n    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<\n\n>\n\n\n\n\n\n\n\n\n\nMenuESPN\n\n\n\n\n\nscores\n\n\n\nNFLNBANCAAFNCAAMNCAAWNHLSoccerMore SportsBoxingNCAACricketF1GamingProfessional WrestlingGolfHorseLLWSMLBMMANASCARNLLNBA G LeagueNBA Summer LeagueNWSLOlympicsPLLRacingRN BBRN FBRugbySports BettingTennisTGLUFLWNBAWWEEditionsWhere to WatchFantasyWatch\n\n\n\n\n\n\n\n\n\n\
# ...

# %%
loader = WebBaseLoader("https://ko.wikipedia.org/wiki/%EB%8C%80%ED%98%95_%EC%96%B8%EC%96%B4_%EB%AA%A8%EB%8D%B8")

# %%
data = loader.load()

# %%
data
# Out:
# [Document(metadata={'source': 'https://ko.wikipedia.org/wiki/%EB%8C%80%ED%98%95_%EC%96%B8%EC%96%B4_%EB%AA%A8%EB%8D%B8', 'title': '대형 언어 모델 - 위키백과, 우리 모두의 백과사전', 'language': 'ko'}, page_content='\n\n\n\n대형 언어 모델 - 위키백과, 우리 모두의 백과사전\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n본문으로 이동\n\n\n\n\n\n\n\n주 메뉴\n\n\n\n\n\n주 메뉴\n사이드바로 이동\n숨기기\n\n\n\n\t\t둘러보기\n\t\n\n\n대문최근 바뀜요즘 화제임의 문서로\n\n\n\n\n\n\t\t사용자 모임\n\t\n\n\n사랑방사용자 모임관리 요청\n\n\n\n\n\n\t\t편집 안내\n\t\n\n\n소개도움말정책과 지침질문방\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n검색\n\n\n\n\n\n\n\n\n\n\n\n검색\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n보이기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n기부\n\n계정 만들기\n\n로그인\n\n\n\n\n\n\n\n\n개인 도구\n\n\n\n\n\n기부 계정 만들기 로그인\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n목차\n사이드바로 이동\n숨기기\n\n\n\n\n처음 위치\n\n\n\n\n\n1\n개요\n\n\n\n\n\n\n\n\n2\n종류\n\n\n\n\n\n\n\n\n3\n역사\n\n\n\n\n\n\n\n\n4\n평가\n\n\n\n\n평가 하위섹션 토글하기\n\n\n\n\n\n4.1\n퍼플렉시티\n\n\n\n\n\n\n\n\n4.2\n작업별 데이터 세트 및 벤치마크\n\n\n\n\n\n\n\n\n\n\n5\n대형 언어 모델
# ...

# %%
# 여러 URL을 같이 load하기
loader = WebBaseLoader(["https://ko.wikipedia.org/wiki/%EB%8C%80%ED%98%95_%EC%96%B8%EC%96%B4_%EB%AA%A8%EB%8D%B8", "https://google.com"])
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'https://ko.wikipedia.org/wiki/%EB%8C%80%ED%98%95_%EC%96%B8%EC%96%B4_%EB%AA%A8%EB%8D%B8', 'title': '대형 언어 모델 - 위키백과, 우리 모두의 백과사전', 'language': 'ko'}, page_content='\n\n\n\n대형 언어 모델 - 위키백과, 우리 모두의 백과사전\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n본문으로 이동\n\n\n\n\n\n\n\n주 메뉴\n\n\n\n\n\n주 메뉴\n사이드바로 이동\n숨기기\n\n\n\n\t\t둘러보기\n\t\n\n\n대문최근 바뀜요즘 화제임의 문서로\n\n\n\n\n\n\t\t사용자 모임\n\t\n\n\n사랑방사용자 모임관리 요청\n\n\n\n\n\n\t\t편집 안내\n\t\n\n\n소개도움말정책과 지침질문방\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n검색\n\n\n\n\n\n\n\n\n\n\n\n검색\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n보이기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n기부\n\n계정 만들기\n\n로그인\n\n\n\n\n\n\n\n\n개인 도구\n\n\n\n\n\n기부 계정 만들기 로그인\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n목차\n사이드바로 이동\n숨기기\n\n\n\n\n처음 위치\n\n\n\n\n\n1\n개요\n\n\n\n\n\n\n\n\n2\n종류\n\n\n\n\n\n\n\n\n3\n역사\n\n\n\n\n\n\n\n\n4\n평가\n\n\n\n\n평가 하위섹션 토글하기\n\n\n\n\n\n4.1\n퍼플렉시티\n\n\n\n\n\n\n\n\n4.2\n작업별 데이터 세트 및 벤치마크\n\n\n\n\n\n\n\n\n\n\n5\n대형 언어 모델
# ...

# %% [markdown]
# # 2. CSVLoader
# *   **CSVLoader는** CSV 파일로부터 모든 text를 load합니다.
# *   각 row 하나를 하나의 document로 load합니다.

# %%
# 예제 csv 파일 다운로드 받기
# !wget https://gist.githubusercontent.com/solaris33/06a3e796ca5aa5f2802fffeaa2f492c1/raw/46394476d39e22e1b4bda873b36a35967f6314f8/mlb_teams_2012.csv -O mlb_teams_2012.csv
# Out:
# --2026-01-30 06:31:09--  https://gist.githubusercontent.com/solaris33/06a3e796ca5aa5f2802fffeaa2f492c1/raw/46394476d39e22e1b4bda873b36a35967f6314f8/mlb_teams_2012.csv
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 847 [text/plain]
# Saving to: ‘mlb_teams_2012.csv’
#
# mlb_teams_2012.csv  100%[===================>]     847  --.-KB/s    in 0s
#
# 2026-01-30 06:31:09 (23.8 MB/s) - ‘mlb_teams_2012.csv’ saved [847/847]

# %%
# !cat mlb_teams_2012.csv
# Out:
# "Team", "Payroll (millions)", "Wins"
# "Nationals",     81.34, 98
# "Reds",          82.20, 97
# "Yankees",      197.96, 95
# "Giants",       117.62, 94
# "Braves",        83.31, 94
# "Athletics",     55.37, 94
# "Rangers",      120.51, 93
# "Orioles",       81.43, 93
# "Rays",          64.17, 90
# "Angels",       154.49, 89
# "Tigers",       132.30, 88
# "Cardinals",    110.30, 88
# "Dodgers",       95.14, 86
# "White Sox",     96.92, 85
# "Brewers",       97.65, 83
# "Phillies",     174.54, 81
# "Diamondbacks",  74.28, 81
# "Pirates",       63.43, 79
# "Padres",        55.24, 76
# "Mariners",      81.97, 75
# "Mets",          93.35, 74
# "Blue Jays",     75.48, 73
# "Royals",        60.91, 72
# "Marlins",      118.07, 69
# "Red Sox",      173.18, 69
# "Indians",       78.43, 68
# "Twins",         94.08, 66
# "Rockies",       78.06, 64
# "Cubs",          88.19, 61
# "Astros",        60.65, 55

# %%
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader(file_path='./mlb_teams_2012.csv')

data = loader.load()

print(data)
# Out:
# [Document(metadata={'source': './mlb_teams_2012.csv', 'row': 0}, page_content='Team: Nationals\n"Payroll (millions)": 81.34\n"Wins": 98'), Document(metadata={'source': './mlb_teams_2012.csv', 'row': 1}, page_content='Team: Reds\n"Payroll (millions)": 82.20\n"Wins": 97'), Document(metadata={'source': './mlb_teams_2012.csv', 'row': 2}, page_content='Team: Yankees\n"Payroll (millions)": 197.96\n"Wins": 95'), Document(metadata={'source': './mlb_teams_2012.csv', 'row': 3}, page_content='Team: Giants\n"Payroll (millions)": 117.62\n"Wins": 94'), Document(metadata={'source': './mlb_teams_2012.csv', 'row': 4}, page_content='Team: Braves\n"Payroll (millions)": 83.31\n"Wins": 94'), Document(metadata={'source': './mlb_teams_2012.csv', 'row': 5}, page_content='Team: Athletics\n"Payroll (millions)": 55.37\n"Wins": 94'), Document(metadata={'source': './mlb_teams_2012.csv', 'row': 6}, page_content='Team: Rangers\n"Payroll (millions)": 120.51\n"Wins": 93'), Document(metadata={'source': './mlb_teams_2
# ...

# %%
# 추가적인 parsing을 진행하고 싶을 경우
loader = CSVLoader(file_path='./mlb_teams_2012.csv', csv_args={
    'delimiter': ',',
    'quotechar': '"', #쌍다운표
    'fieldnames': ['MLB Team', 'Payroll in millions', 'Wins'] #주제 이름 변경
})

data = loader.load()
data
# Out:
# [Document(metadata={'source': './mlb_teams_2012.csv', 'row': 0}, page_content='MLB Team: Team\nPayroll in millions: "Payroll (millions)"\nWins: "Wins"'),
#  Document(metadata={'source': './mlb_teams_2012.csv', 'row': 1}, page_content='MLB Team: Nationals\nPayroll in millions: 81.34\nWins: 98'),
#  Document(metadata={'source': './mlb_teams_2012.csv', 'row': 2}, page_content='MLB Team: Reds\nPayroll in millions: 82.20\nWins: 97'),
#  Document(metadata={'source': './mlb_teams_2012.csv', 'row': 3}, page_content='MLB Team: Yankees\nPayroll in millions: 197.96\nWins: 95'),
#  Document(metadata={'source': './mlb_teams_2012.csv', 'row': 4}, page_content='MLB Team: Giants\nPayroll in millions: 117.62\nWins: 94'),
#  Document(metadata={'source': './mlb_teams_2012.csv', 'row': 5}, page_content='MLB Team: Braves\nPayroll in millions: 83.31\nWins: 94'),
#  Document(metadata={'source': './mlb_teams_2012.csv', 'row': 6}, page_content='MLB Team: Athletics\nPayroll in millions: 55.37\nWins: 94'),
# ...

# %%
# source를 특정 column으로 지정하고 싶을 경우
loader = CSVLoader(file_path='./mlb_teams_2012.csv', source_column="Team") #특정 column에 맞게끔 키 지정

data = loader.load()
data
# Out:
# [Document(metadata={'source': 'Nationals', 'row': 0}, page_content='Team: Nationals\n"Payroll (millions)": 81.34\n"Wins": 98'),
#  Document(metadata={'source': 'Reds', 'row': 1}, page_content='Team: Reds\n"Payroll (millions)": 82.20\n"Wins": 97'),
#  Document(metadata={'source': 'Yankees', 'row': 2}, page_content='Team: Yankees\n"Payroll (millions)": 197.96\n"Wins": 95'),
#  Document(metadata={'source': 'Giants', 'row': 3}, page_content='Team: Giants\n"Payroll (millions)": 117.62\n"Wins": 94'),
#  Document(metadata={'source': 'Braves', 'row': 4}, page_content='Team: Braves\n"Payroll (millions)": 83.31\n"Wins": 94'),
#  Document(metadata={'source': 'Athletics', 'row': 5}, page_content='Team: Athletics\n"Payroll (millions)": 55.37\n"Wins": 94'),
#  Document(metadata={'source': 'Rangers', 'row': 6}, page_content='Team: Rangers\n"Payroll (millions)": 120.51\n"Wins": 93'),
# ...

# %% [markdown]
# # 3. DirectoryLoader
# **DirectoryLoader**는 폴더 안에 존재하는 파일들을 필터링해서 읽어옵니다.

# %%
# !pip install unstructured
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 47.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 22.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.8/167.8 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 64.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.1/329.1 kB 22.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 7.9 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=9205e33e2ba437b149694b9a9a63329a100eb0b40d7e0481ebf176843c4bef88
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader

loader = DirectoryLoader('./sample_data', glob="**/*.md") #glob = 원하는 필터링 ex = 따옴표에 마크다운 형태의 파일만 가져올 것
docs = loader.load()

# %%
len(docs)
# Out:
# 1

# %%
docs
# Out:
# [Document(metadata={'source': 'sample_data/README.md'}, page_content="This directory includes a few sample datasets to get you started.\n\ncalifornia_housing_data*.csv is California housing data from the 1990 US Census; more information is available at: https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub\n\nmnist_*.csv is a small sample of the MNIST database, which is described at: http://yann.lecun.com/exdb/mnist/\n\nanscombe.json contains a copy of Anscombe's quartet; it was originally described in\n\nAnscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American Statistician. 27 (1): 17-21. JSTOR 2682899.\n\nand our copy was prepared by the vega_datasets library.")]

# %%
# loader_cls를 CSVLoader로 지정해서 읽어오기
loader = DirectoryLoader(path='./sample_data', glob="**/california_housing_test.csv", loader_cls=CSVLoader)
docs = loader.load()

# %%
len(docs)
# Out:
# 3000

# %%
docs
# Out:
# [Document(metadata={'source': 'sample_data/california_housing_test.csv', 'row': 0}, page_content='longitude: -122.050000\nlatitude: 37.370000\nhousing_median_age: 27.000000\ntotal_rooms: 3885.000000\ntotal_bedrooms: 661.000000\npopulation: 1537.000000\nhouseholds: 606.000000\nmedian_income: 6.608500\nmedian_house_value: 344700.000000'),
#  Document(metadata={'source': 'sample_data/california_housing_test.csv', 'row': 1}, page_content='longitude: -118.300000\nlatitude: 34.260000\nhousing_median_age: 43.000000\ntotal_rooms: 1510.000000\ntotal_bedrooms: 310.000000\npopulation: 809.000000\nhouseholds: 277.000000\nmedian_income: 3.599000\nmedian_house_value: 176500.000000'),
# ...

# %% [markdown]
# # 4. HTML

# %%
# 예제 html 파일 다운로드 받기
# !wget https://gist.githubusercontent.com/solaris33/f104c7f49ba5db24ea06fd6dfb4c51f9/raw/600a889c5c0eea1c5b82a51877ade446f4bcdf59/sample_html.html -O sample_html.html
# Out:
# --2026-01-30 06:40:59--  https://gist.githubusercontent.com/solaris33/f104c7f49ba5db24ea06fd6dfb4c51f9/raw/600a889c5c0eea1c5b82a51877ade446f4bcdf59/sample_html.html
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 429472 (419K) [text/plain]
# Saving to: ‘sample_html.html’
#
# sample_html.html    100%[===================>] 419.41K  --.-KB/s    in 0.04s
#
# 2026-01-30 06:40:59 (11.4 MB/s) - ‘sample_html.html’ saved [429472/429472]

# %%
from langchain_community.document_loaders import UnstructuredHTMLLoader

loader = UnstructuredHTMLLoader("./sample_html.html")

data = loader.load()
data
# Out:
# [Document(metadata={'source': './sample_html.html'}, page_content='HTML\n\nAfrikaans\n\nAlemannisch\n\nÆnglisc\n\nالعربية\n\nAragonés\n\nঅসমীয়া\n\nAsturianu\n\nAzərbaycanca\n\nتۆرکجه\n\nBasa Bali\n\nবাংলা\n\nBân-lâm-gú\n\nБашҡортса\n\nБеларуская\n\nБеларуская (тарашкевіца)\n\nБългарски\n\nBoarisch\n\nBosanski\n\nBrezhoneg\n\nCatalà\n\nЧӑвашла\n\nČeština\n\nCorsu\n\nCymraeg\n\nDansk\n\nDavvisámegiella\n\nDeutsch\n\nDolnoserbski\n\nEesti\n\nΕλληνικά\n\nEspañol\n\nEsperanto\n\nEuskara\n\nفارسی\n\nFiji Hindi\n\nFøroyskt\n\nFrançais\n\nFrysk\n\nFurlan\n\nGaeilge\n\nGàidhlig\n\nGalego\n\nگیلکی\n\nગુજરાતી\n\n한국어\n\nՀայերեն\n\nहिन्दी\n\nHornjoserbsce\n\nHrvatski\n\nIdo\n\nBahasa Indonesia\n\nInterlingua\n\nÍslenska\n\nItaliano\n\nעברית\n\nJawa\n\nქართული\n\nҚазақша\n\nKiswahili\n\nKurdî\n\nКыргызча\n\nLatgaļu\n\nLatina\n\nLatviešu\n\nLëtzebuergesch\n\nLietuvių\n\nLigure\n\nLingua Franca Nova\n\nLombard\n\nMagyar\n\nमैथिली\n\nМакедонски\n\nMalagasy\n\nമലയാളം\n\nमराठी\n\nBahasa Melayu\n\n閩東語 
# ...

# %%
from langchain_community.document_loaders import BSHTMLLoader

loader = BSHTMLLoader("./sample_html.html")
data = loader.load()
data
# Out:
# [Document(metadata={'source': './sample_html.html', 'title': 'HTML - Wikipedia'}, page_content='\n\n\nHTML - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload file\n\n\n\n\n\nLanguages\n\nLanguage links are at the top of the page across from the title.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\nCreate accountLog in\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\n Create account Log in\n\n\n\n\n\n\t\tPages for logged out editors learn more\n\n\n\nContributionsTalk\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1History\n\n\n\nToggle History subsection\n\n\n\n\n\n1.1Developme
# ...

# %% [markdown]
# # 5. JSONLoader
# **JSONLoader**는 json 파일안의 텍스트를 읽어옵니다. jq 문법을 사용할 수 있습니다.

# %% [markdown]
# ## jq reference : https://en.wikipedia.org/wiki/Jq_(programming_language)

# %%
#JSON 파일 파싱을 위한 라이브러리 설치
# !pip install jq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.8/773.8 kB 10.5 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import JSONLoader

# %%
from pprint import pprint

loader = JSONLoader(
    file_path='./sample_data/anscombe.json',
    jq_schema='.',
    text_content=False)

data = loader.load()
pprint(data)
# Out:
# [Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 1}, page_content='[{"Series": "I", "X": 10, "Y": 8.04}, {"Series": "I", "X": 8, "Y": 6.95}, {"Series": "I", "X": 13, "Y": 7.58}, {"Series": "I", "X": 9, "Y": 8.81}, {"Series": "I", "X": 11, "Y": 8.33}, {"Series": "I", "X": 14, "Y": 9.96}, {"Series": "I", "X": 6, "Y": 7.24}, {"Series": "I", "X": 4, "Y": 4.26}, {"Series": "I", "X": 12, "Y": 10.84}, {"Series": "I", "X": 7, "Y": 4.81}, {"Series": "I", "X": 5, "Y": 5.68}, {"Series": "II", "X": 10, "Y": 9.14}, {"Series": "II", "X": 8, "Y": 8.14}, {"Series": "II", "X": 13, "Y": 8.74}, {"Series": "II", "X": 9, "Y": 8.77}, {"Series": "II", "X": 11, "Y": 9.26}, {"Series": "II", "X": 14, "Y": 8.1}, {"Series": "II", "X": 6, "Y": 6.13}, {"Series": "II", "X": 4, "Y": 3.1}, {"Series": "II", "X": 12, "Y": 9.13}, {"Series": "II", "X": 7, "Y": 7.26}, {"Series": "II", "X": 5, "Y": 4.74}, {"Series": "III", "X": 10, "Y": 7.46}, {"Series": "III", "X": 8, "Y": 6.77}, {"Series": 
# ...

# %%
# [] parsing
loader = JSONLoader(
    file_path='./sample_data/anscombe.json',
    jq_schema='.[]',
    text_content=False)

data = loader.load()
pprint(data)
# Out:
# [Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 1}, page_content='{"Series": "I", "X": 10, "Y": 8.04}'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 2}, page_content='{"Series": "I", "X": 8, "Y": 6.95}'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 3}, page_content='{"Series": "I", "X": 13, "Y": 7.58}'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 4}, page_content='{"Series": "I", "X": 9, "Y": 8.81}'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 5}, page_content='{"Series": "I", "X": 11, "Y": 8.33}'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 6}, page_content='{"Series": "I", "X": 14, "Y": 9.96}'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 7}, page_content='{"Series": "I", "X": 6, "Y": 7.24}'),
# ...

# %%
# Series를 key로 가져오기

loader = JSONLoader(
    file_path='./sample_data/anscombe.json',
    jq_schema='.[].Series', #키 Series만 관련된 데이터만 가져온다
    text_content=False)

data = loader.load()
pprint(data)
# Out:
# [Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 1}, page_content='I'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 2}, page_content='I'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 3}, page_content='I'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 4}, page_content='I'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 5}, page_content='I'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 6}, page_content='I'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 7}, page_content='I'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 8}, page_content='I'),
#  Document(metadata={'source': '/content/sample_data/anscombe.json', 'seq_num': 9}, page_content='I'),
# ...

# %% [markdown]
# # 6. Markdown

# %%
from langchain_community.document_loaders import UnstructuredMarkdownLoader

# %%
markdown_path = "./sample_data/README.md"
loader = UnstructuredMarkdownLoader(markdown_path)
data = loader.load()

# %%
data
# Out:
# [Document(metadata={'source': './sample_data/README.md'}, page_content="This directory includes a few sample datasets to get you started.\n\ncalifornia_housing_data*.csv is California housing data from the 1990 US Census; more information is available at: https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub\n\nmnist_*.csv is a small sample of the MNIST database, which is described at: http://yann.lecun.com/exdb/mnist/\n\nanscombe.json contains a copy of Anscombe's quartet; it was originally described in\n\nAnscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American Statistician. 27 (1): 17-21. JSTOR 2682899.\n\nand our copy was prepared by the vega_datasets library.")]

# %%
# elements mode를 이용해서 전체 md 파일의 텍스트를 분리해서 불러옴
loader = UnstructuredMarkdownLoader(markdown_path, mode="elements") #MD 파일을 분리해서 저장
data = loader.load()

# %%
len(data)
# Out:
# 6

# %%
data
# Out:
# [Document(metadata={'source': './sample_data/README.md', 'languages': ['eng'], 'file_directory': './sample_data', 'filename': 'README.md', 'filetype': 'text/markdown', 'last_modified': '2000-01-01T08:00:00', 'category': 'NarrativeText', 'element_id': 'f908cee4600f7fb28be37d54e5122676'}, page_content='This directory includes a few sample datasets to get you started.'),
#  Document(metadata={'source': './sample_data/README.md', 'languages': ['eng'], 'file_directory': './sample_data', 'filename': 'README.md', 'filetype': 'text/markdown', 'last_modified': '2000-01-01T08:00:00', 'category': 'NarrativeText', 'element_id': '15947199ee55acef9eeffcc77ef28a25'}, page_content='california_housing_data*.csv is California housing data from the 1990 US Census; more information is available at: https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub'),
# ...

# %%
data[0]
# Out:
# Document(metadata={'source': './sample_data/README.md', 'languages': ['eng'], 'file_directory': './sample_data', 'filename': 'README.md', 'filetype': 'text/markdown', 'last_modified': '2000-01-01T08:00:00', 'category': 'NarrativeText', 'element_id': 'f908cee4600f7fb28be37d54e5122676'}, page_content='This directory includes a few sample datasets to get you started.')

# %%
data[1]
# Out:
# Document(metadata={'source': './sample_data/README.md', 'languages': ['eng'], 'file_directory': './sample_data', 'filename': 'README.md', 'filetype': 'text/markdown', 'last_modified': '2000-01-01T08:00:00', 'category': 'NarrativeText', 'element_id': '15947199ee55acef9eeffcc77ef28a25'}, page_content='california_housing_data*.csv is California housing data from the 1990 US Census; more information is available at: https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub')

# %%
data[2]
# Out:
# Document(metadata={'source': './sample_data/README.md', 'link_texts': ['MNIST database'], 'link_urls': ['https://en.wikipedia.org/wiki/MNIST_database'], 'languages': ['eng'], 'file_directory': './sample_data', 'filename': 'README.md', 'filetype': 'text/markdown', 'last_modified': '2000-01-01T08:00:00', 'category': 'NarrativeText', 'element_id': 'c3dc83ee24c396fde3d4fb4d9e87d876'}, page_content='mnist_*.csv is a small sample of the MNIST database, which is described at: http://yann.lecun.com/exdb/mnist/')

# %%
data[3]
# Out:
# Document(metadata={'source': './sample_data/README.md', 'link_texts': ["Anscombe's quartet"], 'link_urls': ['https://en.wikipedia.org/wiki/Anscombe%27s_quartet'], 'languages': ['eng'], 'file_directory': './sample_data', 'filename': 'README.md', 'filetype': 'text/markdown', 'last_modified': '2000-01-01T08:00:00', 'category': 'NarrativeText', 'element_id': '99040d5de0a99d3e7eca340adcbf39c1'}, page_content="anscombe.json contains a copy of Anscombe's quartet; it was originally described in")

# %% [markdown]
# # 7. PDF

# %% [markdown]
# # 예제 pdf : https://arxiv.org/pdf/2302.13971.pdf (Llama 1 페이퍼)

# %%
# !pip install pypdf

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("./llama1_paper.pdf")
pages = loader.load_and_split()

# %%
len(pages)
# Out:
# 36

# %%
# 페이지번호를 page metadata로 가지고 있습니다.
pages[0]
# Out:
# Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-02-28T01:57:46+00:00', 'author': '', 'keywords': '', 'moddate': '2023-02-28T01:57:46+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) kpathsea version 6.3.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': './llama1_paper.pdf', 'total_pages': 27, 'page': 0, 'page_label': '1'}, page_content='LLaMA: Open and Efﬁcient Foundation Language Models\nHugo Touvron∗, Thibaut Lavril∗, Gautier Izacard∗, Xavier Martinet\nMarie-Anne Lachaux, Timothee Lacroix, Baptiste Rozière, Naman Goyal\nEric Hambro, Faisal Azhar, Aurelien Rodriguez, Armand Joulin\nEdouard Grave∗, Guillaume Lample∗\nMeta AI\nAbstract\nWe introduce LLaMA, a collection of founda-\ntion language models ranging from 7B to 65B\nparameters. We train our models on trillions\nof tokens, and show that it is possible to train\nstate-of-the-art models using publicly avail-\nable data
# ...

# %%
pages[1]
# Out:
# Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-02-28T01:57:46+00:00', 'author': '', 'keywords': '', 'moddate': '2023-02-28T01:57:46+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) kpathsea version 6.3.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': './llama1_paper.pdf', 'total_pages': 27, 'page': 0, 'page_label': '1'}, page_content='our models and compare with others LLMs on a set\nof standard benchmarks. Finally, we expose some\nof the biases and toxicity encoded in our models,\nusing some of the most recent benchmarks from\nthe responsible AI community.\narXiv:2302.13971v1  [cs.CL]  27 Feb 2023')

# %%
pages[2]
# Out:
# Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-02-28T01:57:46+00:00', 'author': '', 'keywords': '', 'moddate': '2023-02-28T01:57:46+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) kpathsea version 6.3.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': './llama1_paper.pdf', 'total_pages': 27, 'page': 1, 'page_label': '2'}, page_content='2 Approach\nOur training approach is similar to the methods\ndescribed in previous work (Brown et al., 2020;\nChowdhery et al., 2022), and is inspired by the\nChinchilla scaling laws (Hoffmann et al., 2022).\nWe train large transformers on a large quantity of\ntextual data using a standard optimizer.\n2.1 Pre-training Data\nOur training dataset is a mixture of several sources,\nreported in Table 1, that cover a diverse set of do-\nmains. For the most part, we reuse data sources\nthat have been leveraged to train other LLMs, with\nthe restric
# ...

# %%
# url을 통해서 가져오기
loader = PyPDFLoader("https://arxiv.org/pdf/2302.13971.pdf")
pages = loader.load_and_split()
pages[0]
# Out:
# Document(metadata={'producer': 'pdfTeX-1.40.21', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-02-28T01:57:46+00:00', 'author': '', 'keywords': '', 'moddate': '2023-02-28T01:57:46+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) kpathsea version 6.3.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'https://arxiv.org/pdf/2302.13971.pdf', 'total_pages': 27, 'page': 0, 'page_label': '1'}, page_content='LLaMA: Open and Efﬁcient Foundation Language Models\nHugo Touvron∗, Thibaut Lavril∗, Gautier Izacard∗, Xavier Martinet\nMarie-Anne Lachaux, Timothee Lacroix, Baptiste Rozière, Naman Goyal\nEric Hambro, Faisal Azhar, Aurelien Rodriguez, Armand Joulin\nEdouard Grave∗, Guillaume Lample∗\nMeta AI\nAbstract\nWe introduce LLaMA, a collection of founda-\ntion language models ranging from 7B to 65B\nparameters. We train our models on trillions\nof tokens, and show that it is possible to train\nstate-of-the-art models using publicly
# ...
